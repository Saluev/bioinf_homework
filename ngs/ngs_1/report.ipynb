# %%
import glob
import sys

sys.path.append("../../")

# %% [markdown]
# # 1. GC content

# %%
# See Python files in the same directory for details.
from ngs.ngs_1.gc_content import evaluate_gc_content_distribution

evaluate_gc_content_distribution(
    filenames=glob.glob("/Users/saluev/Downloads/frag.R1*.fastq.gz"), 
    min_base_quality='I',
    min_good_bases_fraction=0.5,
)
# Out:
# Processing reads from file /Users/saluev/Downloads/frag.R1.fastq.gz...
# Reads processed: 1716182 [01:08, 24983.73/s]
# Finished processing file /Users/saluev/Downloads/frag.R1.fastq.gz.
# Total reads processed: 1716182
# Reads discarded due to low quality: 61657 (3.59268%)

# %% [markdown]
# ![](data:image/png;base64,...)

# %% [markdown]
# # 2. Quality distribution

# %%
from ngs.ngs_1.quality import evaluate_quality_distribution

evaluate_quality_distribution(
    filenames=glob.glob("/Users/saluev/Downloads/frag.R1*.fastq.gz"), 
)
# Out:
# Processing reads from file /Users/saluev/Downloads/frag.R1.fastq.gz...
# Reads processed: 1716182 [02:24, 11845.98/s]
# Finished processing file /Users/saluev/Downloads/frag.R1.fastq.gz.
# Total reads processed: 1716182

# %% [markdown]
# ![](data:image/png;base64,...)
